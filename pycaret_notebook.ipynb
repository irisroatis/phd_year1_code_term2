# %%
import pycaret
import pandas as pd
import random

# %%
def pick_only_some(df, target_variable, number):
    df0 = df.loc[df[target_variable] ==0 ]
    df1 = df.loc[df[target_variable] ==1 ]
    how_many_0 = df0.shape[0]
    how_many_1 = df1.shape[0]
    random_indices = random.sample(range(0, how_many_0), how_many_0 - number)
    df0 = df0.drop(df0.index[random_indices])
    random_indices = random.sample(range(0, how_many_1), how_many_1 - number)
    df1 = df1.drop(df1.index[random_indices])
    df = pd.concat([df0, df1])
    return df

# %%
from pycaret.datasets import get_data

# data = pd.read_csv("heart.csv")

data = pd.read_csv("airline_dataset.csv", nrows = 50000)
target_variable = "DEP_DEL15"
data
# Out:
#        MONTH  DAY_OF_WEEK  DEP_DEL15 DEP_TIME_BLK  DISTANCE_GROUP  \
# 0          7            7          0    1500-1559               3
# 1          4            1          0    1300-1359               4
# 2         11            4          0    0001-0559               2
# 3          3            2          0    1500-1559               7
# 4          7            3          0    0800-0859               1
# ...      ...          ...        ...          ...             ...
# 49995      5            7          1    1500-1559               4
# 49996     12            3          0    1600-1659               1
# 49997      4            2          0    0900-0959               5
# 49998      4            1          0    1200-1259               3
# 49999      7            3          1    1800-1859               2
#
#        SEGMENT_NUMBER  CONCURRENT_FLIGHTS  NUMBER_OF_SEATS  \
# 0                   3                  26              160
# 1                   4                  63               50
# 2                   1                   3               76
# 3                   5                  14              143
# 4                   2                  85               50
# ...               ...                 ...              ...
# 49995               4                  11              178
# 49996               4                  48              129
# 49997               1                   6              154
# 49998               2                  27              154
# 49999               5                   4              143
#
#                        CARRIER_NAME  AIRPORT_FLIGHTS_MONTH  ...  \
# 0            American Airlines Inc.                  19534  ...
# 1             SkyWest Airlines Inc.                  18788  ...
# 2      American Eagle Airlines Inc.                   1148  ...
# 3            Southwest Airlines Co.                   7612  ...
# 4      American Eagle Airlines Inc.                  29376  ...
# ...                             ...                    ...  ...
# 49995              Spirit Air Lines                  14978  ...
# 49996   Atlantic Southeast Airlines                  15165  ...
# 49997         United Air Lines Inc.                   3690  ...
# 49998         United Air Lines Inc.                  13675  ...
# 49999        Southwest Airlines Co.                   1441  ...
#
#                                  PREVIOUS_AIRPORT  PRCP  SNOW  SNWD   TMAX  \
# 0                    Chicago O'Hare International  0.00   0.0   0.0   95.0
# 1                           El Paso International  0.00   0.0   0.0   71.0
# 2                                            NONE  0.00   0.0   0.0   54.0
# 3                          San Jose International  0.00   0.0   0.0   64.0
# 4      Cincinnati/Northern Kentucky International  0.01   0.0   0.0   94.0
# ...                                           ...   ...   ...   ...    ...
# 49995                    Friendship International  0.00   0.0   0.0   88.0
# 49996                      Allen C Thompson Field  0.00   0.0   0.0   84.0
# 49997                                        NONE  0.00   0.0   0.0   87.0
# 49998     Fort Lauderdale-Hollywood International  0.00   0.0   0.0   77.0
# 49999        San Diego International Lindbergh Fl  0.00   0.0   0.0  101.0
#
#         AWND  CARRIER_HISTORICAL DEP_AIRPORT_HIST  DAY_HISTORICAL  \
# 0       4.25            0.237709         0.273236        0.222538
# 1      11.41            0.154651         0.121849        0.237972
# 2       0.45            0.117559         0.187867        0.139886
# 3       8.05            0.204389         0.141446        0.132868
# 4      10.51            0.203263         0.193761        0.203027
# ...      ...                 ...              ...             ...
# 49995   6.71            0.226031         0.241041        0.211331
# 49996  13.65            0.243554         0.187867        0.196265
# 49997   8.50            0.183223         0.187867        0.138603
# 49998   9.84            0.183223         0.225439        0.237972
# 49999  12.08            0.215945         0.161329        0.203027
#
#        DEP_BLOCK_HIST
# 0            0.255479
# 1            0.197503
# 2            0.060327
# 3            0.202037
# 4            0.113050
# ...               ...
# 49995        0.242114
# 49996        0.249617
# 49997        0.135374
# 49998        0.181934
# 49999        0.326393
#
# [50000 rows x 30 columns]

# %%
# data =  pick_only_some(data, target_variable, 4000)

# data

# %%
from pycaret.classification import *
exp = ClassificationExperiment()
type(exp)
# Out:
# pycaret.classification.oop.ClassificationExperiment

# %%
# exp.setup(data, target = "target") ### this is for heart dataset
# exp.setup(data, target = target_variable) ### this is for airline dataset
exp.setup(data, target = target_variable, fix_imbalance = True) ### this is for airline dataset
# Out:
# <style type="text/css">
# #T_fe8dd_row9_col1, #T_fe8dd_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fe8dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe8dd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fe8dd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe8dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe8dd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fe8dd_row0_col1" class="data row0 col1" >6018</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fe8dd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fe8dd_row1_col1" class="data row1 col1" >DEP_DEL15</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fe8dd_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_fe8dd_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fe8dd_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_fe8dd_row3_col1" class="data row3 col1" >(50000, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fe8dd_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_fe8dd_row4_col1" class="data row4 col1" >(71728, 64)</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fe8dd_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_fe8dd_row5_col1" class="data row5 col1" >(56728, 64)</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fe8dd_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_fe8dd_row6_col1" class="data row6 col1" >(15000, 64)</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fe8dd_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_fe8dd_row7_col1" class="data row7 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fe8dd_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_fe8dd_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fe8dd_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_fe8dd_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fe8dd_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_fe8dd_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fe8dd_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_fe8dd_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fe8dd_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_fe8dd_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fe8dd_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_fe8dd_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fe8dd_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_fe8dd_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fe8dd_row15_col0" class="data row15 col0" >Fix imbalance</td>
#       <td id="T_fe8dd_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fe8dd_row16_col0" class="data row16 col0" >Fix imbalance method</td>
#       <td id="T_fe8dd_row16_col1" class="data row16 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fe8dd_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_fe8dd_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fe8dd_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_fe8dd_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fe8dd_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_fe8dd_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_fe8dd_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_fe8dd_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_fe8dd_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_fe8dd_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_fe8dd_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_fe8dd_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_fe8dd_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_fe8dd_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_fe8dd_row23_col1" class="data row23 col1" >215c</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = exp.compare_models()
# Out:
# <style type="text/css">
# #T_ec6b5 th {
#   text-align: left;
# }
# #T_ec6b5_row0_col0, #T_ec6b5_row0_col2, #T_ec6b5_row0_col3, #T_ec6b5_row0_col4, #T_ec6b5_row0_col5, #T_ec6b5_row0_col6, #T_ec6b5_row0_col7, #T_ec6b5_row1_col0, #T_ec6b5_row1_col1, #T_ec6b5_row1_col3, #T_ec6b5_row1_col5, #T_ec6b5_row1_col6, #T_ec6b5_row1_col7, #T_ec6b5_row2_col0, #T_ec6b5_row2_col1, #T_ec6b5_row2_col2, #T_ec6b5_row2_col3, #T_ec6b5_row2_col4, #T_ec6b5_row2_col5, #T_ec6b5_row2_col6, #T_ec6b5_row2_col7, #T_ec6b5_row3_col0, #T_ec6b5_row3_col1, #T_ec6b5_row3_col2, #T_ec6b5_row3_col3, #T_ec6b5_row3_col4, #T_ec6b5_row3_col5, #T_ec6b5_row3_col6, #T_ec6b5_row3_col7, #T_ec6b5_row4_col0, #T_ec6b5_row4_col1, #T_ec6b5_row4_col2, #T_ec6b5_row4_col3, #T_ec6b5_row4_col4, #T_ec6b5_row4_col5, #T_ec6b5_row4_col6, #T_ec6b5_row4_col7, #T_ec6b5_row5_col0, #T_ec6b5_row5_col1, #T_ec6b5_row5_col2, #T_ec6b5_row5_col3, #T_ec6b5_row5_col4, #T_ec6b5_row5_col5, #T_ec6b5_row5_col6, #T_ec6b5_row5_col7, #T_ec6b5_row6_col0, #T_ec6b5_row6_col1, #T_ec6b5_row6_col2, #T_ec6b5_row6_col3, #T_ec6b5_row6_col4, #T_ec6b5_row6_col5, #T_ec6b5_row6_col6, #T_ec6b5_row6_col7, #T_ec6b5_row7_col0, #T_ec6b5_row7_col1, #T_ec6b5_row7_col2, #T_ec6b5_row7_col3, #T_ec6b5_row7_col4, #T_ec6b5_row8_col0, #T_ec6b5_row8_col1, #T_ec6b5_row8_col2, #T_ec6b5_row8_col3, #T_ec6b5_row8_col4, #T_ec6b5_row8_col5, #T_ec6b5_row8_col6, #T_ec6b5_row8_col7, #T_ec6b5_row9_col0, #T_ec6b5_row9_col1, #T_ec6b5_row9_col2, #T_ec6b5_row9_col3, #T_ec6b5_row9_col4, #T_ec6b5_row9_col5, #T_ec6b5_row9_col6, #T_ec6b5_row9_col7, #T_ec6b5_row10_col0, #T_ec6b5_row10_col1, #T_ec6b5_row10_col2, #T_ec6b5_row10_col3, #T_ec6b5_row10_col4, #T_ec6b5_row10_col5, #T_ec6b5_row10_col6, #T_ec6b5_row10_col7, #T_ec6b5_row11_col0, #T_ec6b5_row11_col1, #T_ec6b5_row11_col2, #T_ec6b5_row11_col3, #T_ec6b5_row11_col4, #T_ec6b5_row11_col5, #T_ec6b5_row11_col6, #T_ec6b5_row11_col7, #T_ec6b5_row12_col0, #T_ec6b5_row12_col1, #T_ec6b5_row12_col2, #T_ec6b5_row12_col4, #T_ec6b5_row12_col5, #T_ec6b5_row12_col6, #T_ec6b5_row12_col7 {
#   text-align: left;
# }
# #T_ec6b5_row0_col1, #T_ec6b5_row1_col2, #T_ec6b5_row1_col4, #T_ec6b5_row7_col5, #T_ec6b5_row7_col6, #T_ec6b5_row7_col7, #T_ec6b5_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ec6b5_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_ec6b5_row1_col8, #T_ec6b5_row2_col8, #T_ec6b5_row3_col8, #T_ec6b5_row4_col8, #T_ec6b5_row5_col8, #T_ec6b5_row6_col8, #T_ec6b5_row7_col8, #T_ec6b5_row8_col8, #T_ec6b5_row9_col8, #T_ec6b5_row10_col8, #T_ec6b5_row11_col8, #T_ec6b5_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ec6b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec6b5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ec6b5_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ec6b5_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ec6b5_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ec6b5_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ec6b5_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ec6b5_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ec6b5_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ec6b5_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec6b5_level0_row0" class="row_heading level0 row0" >dummy</th>
#       <td id="T_ec6b5_row0_col0" class="data row0 col0" >Dummy Classifier</td>
#       <td id="T_ec6b5_row0_col1" class="data row0 col1" >0.8104</td>
#       <td id="T_ec6b5_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_ec6b5_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_ec6b5_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_ec6b5_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_ec6b5_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_ec6b5_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_ec6b5_row0_col8" class="data row0 col8" >0.1350</td>
#     </tr>
#     <tr>
#       <th id="T_ec6b5_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_ec6b5_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_ec6b5_row1_col1" class="data row1 col1" >0.8080</td>
#       <td id="T_ec6b5_row1_col2" class="data row1 col2" >0.6775</td>
#       <td id="T_ec6b5_row1_col3" class="data row1 col3" >0.1275</td>
#       <td id="T_ec6b5_row1_col4" class="data row1 col4" >0.4766</td>
#       <td id="T_ec6b5_row1_col5" class="data row1 col5" >0.2010</td>
#       <td id="T_ec6b5_row1_col6" class="data row1 col6" >0.1315</td>
#       <td id="T_ec6b5_row1_col7" class="data row1 col7" >0.1691</td>
#       <td id="T_ec6b5_row1_col8" class="data row1 col8" >3.2960</td>
#     </tr>
#     <tr>
#       <th id="T_ec6b5_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_ec6b5_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_ec6b5_row2_col1" class="data row2 col1" >0.8014</td>
#       <td id="T_ec6b5_row2_col2" class="data row2 col2" >0.6680</td>
#       <td id="T_ec6b5_row2_col3" class="data row2 col3" >0.1337</td>
#       <td id="T_ec6b5_row2_col4" class="data row2 col4" >0.4236</td>
#       <td id="T_ec6b5_row2_col5" class="data row2 col5" >0.2031</td>
#       <td id="T_ec6b5_row2_col6" class="data row2 col6" >0.1236</td>
#       <td id="T_ec6b5_row2_col7" class="data row2 col7" >0.1507</td>
#       <td id="T_ec6b5_row2_col8" class="data row2 col8" >5.8460</td>
#     </tr>
#     <tr>
#       <th id="T_ec6b5_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_ec6b5_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_ec6b5_row3_col1" class="data row3 col1" >0.7998</td>
#       <td id="T_ec6b5_row3_col2" class="data row3 col2" >0.6664</td>
#       <td id="T_ec6b5_row3_col3" class="data row3 col3" >0.1511</td>
#       <td id="T_ec6b5_row3_col4" class="data row3 col4" >0.4221</td>
#       <td id="T_ec6b5_row3_col5" class="data row3 col5" >0.2223</td>
#       <td id="T_ec6b5_row3_col6" class="data row3 col6" >0.1360</td>
#       <td id="T_ec6b5_row3_col7" class="data row3 col7" >0.1599</td>
#       <td id="T_ec6b5_row3_col8" class="data row3 col8" >6.3750</td>
#     </tr>
#     <tr>
#       <th id="T_ec6b5_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_ec6b5_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_ec6b5_row4_col1" class="data row4 col1" >0.7618</td>
#       <td id="T_ec6b5_row4_col2" class="data row4 col2" >0.6302</td>
#       <td id="T_ec6b5_row4_col3" class="data row4 col3" >0.2422</td>
#       <td id="T_ec6b5_row4_col4" class="data row4 col4" >0.3293</td>
#       <td id="T_ec6b5_row4_col5" class="data row4 col5" >0.2782</td>
#       <td id="T_ec6b5_row4_col6" class="data row4 col6" >0.1397</td>
#       <td id="T_ec6b5_row4_col7" class="data row4 col7" >0.1425</td>
#       <td id="T_ec6b5_row4_col8" class="data row4 col8" >1.5910</td>
#     </tr>
#     <tr>
#       <th id="T_ec6b5_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_ec6b5_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_ec6b5_row5_col1" class="data row5 col1" >0.7069</td>
#       <td id="T_ec6b5_row5_col2" class="data row5 col2" >0.5480</td>
#       <td id="T_ec6b5_row5_col3" class="data row5 col3" >0.2920</td>
#       <td id="T_ec6b5_row5_col4" class="data row5 col4" >0.2585</td>
#       <td id="T_ec6b5_row5_col5" class="data row5 col5" >0.2742</td>
#       <td id="T_ec6b5_row5_col6" class="data row5 col6" >0.0915</td>
#       <td id="T_ec6b5_row5_col7" class="data row5 col7" >0.0918</td>
#       <td id="T_ec6b5_row5_col8" class="data row5 col8" >0.5160</td>
#     </tr>
#     <tr>
#       <th id="T_ec6b5_level0_row6" class="row_heading level0 row6" >knn</th>
#       <td id="T_ec6b5_row6_col0" class="dat
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
