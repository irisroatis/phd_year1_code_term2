# %%
conda install lightgbm
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::holoviews==1.15.0=py39hecd8cb5_0
#   - defaults/noarch::conda-pack==0.6.0=pyhd3eb1b0_0
#   - defaults/osx-64::scikit-learn==1.0.2=py39hae1ba45_1
#   - defaults/noarch::nbclassic==0.3.5=pyhd3eb1b0_0
#   - defaults/noarch::cookiecutter==1.7.3=pyhd3eb1b0_0
#   - defaults/osx-64::anaconda-project==0.11.1=py39hecd8cb5_0
#   - defaults/noarch::importlib_metadata==4.11.3=hd3eb1b0_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.4=pyhd3eb1b0_0
#   - defaults/noarch::pyls-spyder==0.4.0=pyhd3eb1b0_0
#   - defaults/osx-64::scikit-learn-intelex==2021.6.0=py39hecd8cb5_0
#   - defaults/osx-64::jupyterlab==3.4.4=py39hecd8cb5_0
#   - defaults/osx-64::datashader==0.14.1=py39hecd8cb5_0
#   - defaults/osx-64::anaconda==2022.10=py39_0
#   - defaults/osx-64::scrapy==2.6.2=py39hecd8cb5_0
#   - defaults/noarch::jinja2==2.11.3=pyhd3eb1b0_0
#   - defaults/osx-64::hvplot==0.8.0=py39hecd8cb5_0
#   - defaults/noarch::nltk==3.7=pyhd3eb1b0_0
#   - defaults/osx-64::python-lsp-black==1.2.1=py39hecd8cb5_0
#   - defaults/noarch::flake8==4.0.1=pyhd3eb1b0_1
#   - defaults/osx-64::qtconsole==5.3.2=py39hecd8cb5_0
#   - defaults/osx-64::ipython==7.31.1=py39hecd8cb5_1
#   - defaults/osx-64::conda-build==3.22.0=py39hecd8cb5_0
#   - defaults/osx-64::sphinx==5.0.2=py39hecd8cb5_0
#   - defaults/osx-64::bcrypt==3.2.0=py39hca72f7f_1
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_1
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/osx-64::python-lsp-server==1.5.0=py39hecd8cb5_0
#   - defaults/osx-64::dask==2022.7.0=py39hecd8cb5_0
#   - defaults/osx-64::anaconda-navigator==2.3.1=py39hecd8cb5_0
#   - defaults/osx-64::jupyter_server==1.18.1=py39hecd8cb5_0
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_3
#   - defaults/osx-64::anaconda-client==1.11.0=py39hecd8cb5_0
#   - defaults/osx-64::spyder-kernels==2.3.3=py39hecd8cb5_0
#   - defaults/noarch::jupyterlab_server==2.10.3=pyhd3eb1b0_1
#   - defaults/osx-64::nbconvert==6.4.4=py39hecd8cb5_0
#   - defaults/osx-64::numpydoc==1.4.0=py39hecd8cb5_0
#   - defaults/osx-64::zope.interface==5.4.0=py39h9ed2024_0
#   - defaults/osx-64::numba==0.55.1=py39hae1ba45_0
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/noarch::intake==0.6.5=pyhd3eb1b0_0
#   - defaults/osx-64::keyring==23.4.0=py39hecd8cb5_0
#   - defaults/osx-64::conda==22.9.0=py39hecd8cb5_0
#   - defaults/osx-64::navigator-updater==0.3.0=py39hecd8cb5_0
#   - defaults/osx-64::distributed==2022.7.0=py39hecd8cb5_0
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_8
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/noarch::jupyter_console==6.4.3=pyhd3eb1b0_0
#   - defaults/osx-64::markdown==3.3.4=py39hecd8cb5_0
#   - defaults/osx-64::bokeh==2.4.3=py39hecd8cb5_0
#   - defaults/osx-64::twisted==22.2.0=py39hca72f7f_1
#   - defaults/osx-64::conda-repo-cli==1.0.20=py39hecd8cb5_0
#   - defaults/osx-64::ipykernel==6.15.2=py39hecd8cb5_0
#   - defaults/noarch::conda-token==0.4.0=pyhd3eb1b0_0
#   - defaults/osx-64::spyder==5.3.3=py39hecd8cb5_0
#   - defaults/osx-64::notebook==6.4.12=py39hecd8cb5_0
#   - defaults/osx-64::panel==0.13.1=py39hecd8cb5_0
#   - defaults/osx-64::widgetsnbextension==3.5.2=py39hecd8cb5_0
#   - defaults/osx-64::clyent==1.2.2=py39hecd8cb5_1
#   - defaults/noarch::xarray==0.20.1=pyhd3eb1b0_1
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::holoviews==1.15.0=py39hecd8cb5_0
#   - defaults/noarch::conda-pack==0.6.0=pyhd3eb1b0_0
#   - defaults/osx-64::scikit-learn==1.0.2=py39hae1ba45_1
#   - defaults/noarch::nbclassic==0.3.5=pyhd3eb1b0_0
#   - defaults/noarch::cookiecutter==1.7.3=pyhd3eb1b0_0
#   - defaults/osx-64::anaconda-project==0.11.1=py39hecd8cb5_0
#   - defaults/noarch::importlib_metadata==4.11.3=hd3eb1b0_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.4=pyhd3eb1b0_0
#   - defaults/noarch::pyls-spyder==0.4.0=pyhd3eb1b0_0
#   - defaults/osx-64::scikit-learn-intelex==2021.6.0=py39hecd8cb5_0
#   - defaults/osx-64::jupyterlab==3.4.4=py39hecd8cb5_0
#   - defaults/osx-64::datashader==0.14.1=py39hecd8cb5_0
#   - defaults/osx-64::anaconda==2022.10=py39_0
#   - defaults/osx-64::scrapy==2.6.2=py39hecd8cb5_0
#   - defaults/noarch::jinja2==2.11.3=pyhd3eb1b0_0
#   - defaults/osx-64::hvplot==0.8.0=py39hecd8cb5_0
#   - defaults/noarch::nltk==3.7=pyhd3eb1b0_0
#   - defaults/osx-64::python-lsp-black==1.2.1=py39hecd8cb5_0
#   - defaults/noarch::flake8==4.0.1=pyhd3eb1b0_1
#   - defaults/osx-64::qtconsole==5.3.2=py39hecd8cb5_0
#   - defaults/osx-64::ipython==7.31.1=py39hecd8cb5_1
#   - defaults/osx-64::conda-build==3.22.0=py39hecd8cb5_0
#   - defaults/osx-64::sphinx==5.0.2=py39hecd8cb5_0
#   - defaults/osx-64::bcrypt==3.2.0=py39hca72f7f_1
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_1
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/osx-64::python-lsp-server==1.5.0=py39hecd8cb5_0
#   - defaults/osx-64::dask==2022.7.0=py39hecd8cb5_0
#   - defaults/osx-64::anaconda-navigator==2.3.1=py39hecd8cb5_0
#   - defaults/osx-64::jupyter_server==1.18.1=py39hecd8cb5_0
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_3
#   - defaults/osx-64::anaconda-client==1.11.0=py39hecd8cb5_0
#   - defaults/osx-64::spyder-kernels==2.3.3=py39hecd8cb5_0
#   - defaults/noarch::jupyterlab_server==2.10.3=pyhd3eb1b0_1
#   - defaults/osx-64::nbconvert==6.4.4=py39hecd8cb5_0
#   - defaults/osx-64::numpydoc==1.4.0=py39hecd8cb5_0
#   - defaults/osx-64::zope.interface==5.4.0=py39h9ed2024_0
#   - defaults/osx-64::numba==0.55.1=py39hae1ba45_0
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/noarch::intake==0.6.5=pyhd3eb1b0_0
#   - defaults/osx-64::keyring==23.4.0=py39hecd8cb5_0
#   - defaults/osx-64::conda==22.9.0=py39hecd8cb5_0
#   - defaults/osx-64::navigator-updater==0.3.0=py39hecd8cb5_0
#   - defaults/osx-64::distributed==2022.7.0=py39hecd8cb5_0
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_8
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/noarch::jupyter_console==6.4.3=pyhd3eb1b0_0
#   - defaults/osx-64::markdown==3.3.4=py39hecd8cb5_0
#   - defaults/osx-64::bokeh==2.4.3=py39hecd8cb5_0
#   - defaults/osx-64::twisted==22.2.0=py39hca72f7f_1
#   - defaults/osx-64::conda-repo-cli==1.0.20=py39hecd8cb5_0
#   - defaults/osx-64::ipykernel==6.15.2=py39hecd8cb5_0
#   - defaults/noarch::conda-token==0.4.0=pyhd3eb1b0_0
#   - defaults/osx-64::spyder==5.3.3=py39hecd8cb5_0
#   - defaults/osx-64::notebook==6.4.12=py39hecd8cb5_0
#   - defaults/osx-64::panel==0.13.1=py39hecd8cb5_0
#   - defaults/osx-64::widgetsnbextension==3.5.2=py39hecd8cb5_0
#   - defaults/osx-64::clyent==1.2.2=py39hecd8cb5_1
#   - defaults/noarch::xarray==0.20.1=pyhd3eb1b0_1
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/roatisiris/opt/anaconda3
#
#   added / updated specs:
#     - lightgbm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2022.10  |           py39_2          69 KB
#     anaconda-custom            |           py39_1           4 KB
#     certifi-2023.5.7           |   py39hecd8cb5_0         153 KB
#     joblib-1.1.1               |   py39hecd8cb5_0         384 KB
#     lightgbm-3.3.5             |   py39hcec6c5f_0         1.1 MB
#     pip-23.0.1                 |   py39hecd8cb5_0         2.5 MB
#     setuptools-66.0.0          |   py39hecd8cb5_0         1.2 MB
#     wheel-0.38.4               |   py39hecd8cb5_0          65 KB
#     ------------------------------------------------------------
#                                            Total:         5.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-2022.10-py39_2 None
#   importlib-metadata pkgs/main/osx-64::importlib-metadata-4.11.3-py39hecd8cb5_0 None
#   joblib             pkgs/main/osx-64::joblib-1.1.1-py39hecd8cb5_0 None
#   lightgbm           pkgs/main/osx-64::lightgbm-3.3.5-py39hcec6c5f_0 None
#   pip                pkgs/main/osx-64::pip-23.0.1-py39hecd8cb5_0 None
#   setuptools         pkgs/main/osx-64::setuptools-66.0.0-py39hecd8cb5_0 None
#   wheel              pkgs/main/osx-64::wheel-0.38.4-py39hecd8cb5_0 None
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2022.07.19-hecd8cb5_0 --> 2023.01.10-hecd8cb5_0 None
#   certifi                          2022.9.24-py39hecd8cb5_0 --> 2023.5.7-py39hecd8cb5_0 None
#   openssl                                 1.1.1q-hca72f7f_0 --> 1.1.1t-hca72f7f_0 None
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2022.10-py39_0 --> custom-py39_1 None
#
#
#
# Downloading and Extracting Packages
# anaconda-custom      | 4 KB      | ##################################### | 100%
# lightgbm-3.3.5       | 1.1 MB    | ##################################### | 100%
# pip-23.0.1           | 2.5 MB    | ##################################### | 100%
# setuptools-66.0.0    | 1.2 MB    | ##################################### | 100%
# _anaconda_depends-20 | 69 KB     | ##################################### | 100%
# joblib-1.1.1         | 384 KB    | ##################################### | 100%
# certifi-2023.5.7     | 153 KB    | ##################################### | 100%
# wheel-0.38.4         | 65 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'setuptools' is a dependency of conda and cannot be removed from
# conda's operating environment.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pycaret
import pandas as pd
from pycaret.classification import *

# %%
from pycaret.datasets import get_data
data = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %%
from pycaret.classification import ClassificationExperiment
exp = ClassificationExperiment()
type(exp)
# Out:
# pycaret.classification.oop.ClassificationExperiment

# %%
exp.setup(data, target = 'Class variable')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/k9/zm7n9vnd3tlgxr507krf8yjc0000gn/T/ipykernel_36933/4069045755.py in <module>
# ----> 1 exp.setup(data, target = 'Class variable')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/classification/oop.py in setup(self, data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, group_names, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, memory, profile, profile_kwargs)
#     783         )
#     784
# --> 785         self._set_exp_model_engines(
#     786             container_default_engines=get_container_default_engines(),
#     787             engine=engine,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py in _set_exp_model_engines(self, container_default_engines, engine)
#    2888             # If provided by user, then use that, else get from the defaults
#    2889             eng = engine.get(key, container_default_engines.get(key))
# -> 2890             self._set_engine(estimator=key, engine=eng, severity="error")
#    2891
#    2892         return self
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py in _set_engine(self, estimator, engine, severity)
#    2854
#    2855         # Need to do this, else internal class variables are not reset with new engine.
# -> 2856         self._set_all_models()
#    2857
#    2858     def _set_exp_model_engines(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py in _set_all_models(self)
#    2744             The experiment object to allow chaining of methods
#    2745         """
# -> 2746         self._all_models, self._all_models_internal = self._get_models()
#    2747         return self
#    2748
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/classification/oop.py in _get_models(self, raise_errors)
#      82         all_models = {
#      83             k: v
# ---> 84             for k, v in get_all_class_model_containers(
#      85                 self, raise_errors=raise_errors
#      86             ).items()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/containers/models/classification.py in get_all_model_containers(experiment, raise_errors)
#    1638     experiment: Any, raise_errors: bool = True
#    1639 ) -> Dict[str, ClassifierContainer]:
# -> 1640     return pycaret.containers.base_container.get_all_containers(
#    1641         globals(), experiment, ClassifierContainer, raise_errors
#    1642     )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/containers/base_container.py in get_all_containers(container_globals, experiment, type_var, raise_errors)
#     117             if hasattr(obj, "active") and not obj.active:
#     118                 continue
# --> 119             instance = obj(experiment)
#     120             if instance.active:
#     121                 model_containers.append(instance)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/containers/models/classification.py in __init__(self, experiment)
#    1252         get_logger()
#    1253         np.random.seed(experiment.seed)
# -> 1254         from lightgbm import LGBMClassifier
#    1255         from lightgbm.basic import LightGBMError
#    1256
#
# ~/opt/anaconda3/lib/python3.9/site-packages/lightgbm/__init__.py in <module>
#       6 from pathlib import Path
#       7
# ----> 8 from .basic import Booster, Dataset, Sequence, register_logger
#       9 from .callback import early_stopping, log_evaluation, print_evaluation, record_evaluation, reset_parameter
#      10 from .engine import CVBooster, cv, train
#
# ~/opt/anaconda3/lib/python3.9/site-packages/lightgbm/basic.py in <module>
#     108
#     109
# --> 110 _LIB = _load_lib()
#     111
#     112
#
# ~/opt/anaconda3/lib/python3.9/site-packages/lightgbm/basic.py in _load_lib()
#      99     if len(lib_path) == 0:
#     100         return None
# --> 101     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#     102     lib.LGBM_GetLastError.restype = ctypes.c_char_p
#     103     callback = ctypes.CFUNCTYPE(None, ctypes.c_char_p)
#
# ~/opt/anaconda3/lib/python3.9/ctypes/__init__.py in LoadLibrary(self, name)
#     458
#     459     def LoadLibrary(self, name):
# --> 460         return self._dlltype(name)
#     461
#     462     __class_getitem__ = classmethod(_types.GenericAlias)
#
# ~/opt/anaconda3/lib/python3.9/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     380
#     381         if handle is None:
# --> 382             self._handle = _dlopen(self._name, mode)
#     383         else:
#     384             self._handle = handle
#
# OSError: dlopen(/Users/roatisiris/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/roatisiris/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)

# %%
best = excompare_models()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/k9/zm7n9vnd3tlgxr507krf8yjc0000gn/T/ipykernel_36933/793640792.py in <module>
# ----> 1 best = compare_models()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     962             for name, message in global_names.items():
#     963                 if globals_d[name] is None:
# --> 964                     raise ValueError(message)
#     965             return func(*args, **kwargs)
#     966
#
# ValueError: _CURRENT_EXPERIMENT global variable is not set. Please run setup() first.
